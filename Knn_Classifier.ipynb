# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

column_names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]
training_data = pd.read_csv('train_IRIS',index_col=0)
test_data = pd.read_csv('test_IRIS',index_col=0)

# Scatterplot of sepal length vs. sepal width
sns.scatterplot(x="s_l", y="s_w", hue="class", data=training_data)
plt.title("Sepal Length vs. Sepal Width")
plt.show()

# Scatterplot of sepal length vs. sepal width
sns.scatterplot(x="p_l", y="p_w", hue="class", data=training_data)
plt.title("Petal Length vs. Petal Width")
plt.show()

# Scatterplot of sepal length vs. sepal width
sns.scatterplot(x="s_l", y="p_l", hue="class", data=training_data)
plt.title("Sepal Length vs. Petal Length")
plt.show()

# Scatterplot of sepal length vs. sepal width
sns.scatterplot(x="p_w", y="s_w", hue="class", data=training_data)
plt.title("Petal Width vs. Sepal Width")
plt.show()

X_train = training_data.drop("class", axis=1)
y_train = training_data["class"]

X_test = test_data.drop("class", axis=1)
y_test = test_data["class"]

k_values = [1, 7, 10]
for k in k_values:
    # Create a k-NN classifier with k = 1, 7, or 10
    knn = KNeighborsClassifier(n_neighbors=k)

    knn.fit(X_train, y_train)

    y_pred = knn.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    print(f"k = {k}: Accuracy = {accuracy:.2f}")
# Out:
# k = 1: Accuracy = 1.00
# k = 7: Accuracy = 0.98
# k = 10: Accuracy = 0.98
